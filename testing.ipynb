# %%
import requests
import json

# %%
def fetch_data_from_url(url):
    try:
        # Send a GET request to the specified URL
        response = requests.get(url)
        
        # Check if the request was successful
        if response.status_code == 200:
            # Return the content of the response
            return response.content
        else:
            # Handle unsuccessful requests
            print(f"Failed to retrieve data. Status code: {response.status_code}")
            return None
    except requests.exceptions.RequestException as e:
        # Handle any exceptions that occur during the request
        print(f"An error occurred: {e}")
        return None

# %%
# Example usage
url = "http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2024/types/3/weeks/1/events"
data = json.loads(fetch_data_from_url(url).decode())


team_stats = {"JJ": [{"id": "3918298", "name": "Big Josh", "in": True, "points": 0},
{"id": "3042519", "name": "Aaron Jones", "in": True, "points": 0},
{"id": "4697815", "name": "Rashaad White", "in": True, "points": 0},
{"id": "15828", "name": "AJ Brown", "in": True, "points": 0},
{"id": "4360939", "name": "Bateman", "in": True, "points": 0},
{"id": "15847", "name": "T Kelce", "in": True, "points": 0},
{"id": "15795", "name": "D Hop", "in": True, "points": 0}],
"BNIED": [{"id": "12483", "name": "Stafford", "in": True, "points": 0},
{"id": "4047365", "name": "J Jacobs", "in": True, "points": 0},
{"id": "4430737", "name": "Kyrien Williams", "in": True, "points": 0},
{"id": "4374302", "name": "Amon Ra", "in": True, "points": 0},
{"id": "4426515", "name": "Puka Nacua", "in": True, "points": 0},
{"id": "3116365", "name": "Mark Andrews", "in": True, "points": 0},
{"id": "4373678", "name": "Khalil Shakir", "in": True, "points": 0}],
"QUINN": [{"id": "4040715", "name": "J Hurts", "in": True, "points": 0},
{"id": "3116385", "name": "Mixon", "in": True, "points": 0},
{"id": "4241474", "name": "B Rob", "in": True, "points": 0},
{"id": "4262921", "name": "JJetas", "in": True, "points": 0},
{"id": "16737", "name": "Mike Evans", "in": True, "points": 0},
{"id": "4429615", "name": "Zay Flowers", "in": True, "points": 0},
{"id": "3121422", "name": "Scary Terry", "in": True, "points": 0}],
"JONO": [{"id": "3916387", "name": "Lamar", "in": True, "points": 0},
{"id": "4241985", "name": "JK", "in": True, "points": 0},
{"id": "4038441", "name": "Justice Hill", "in": True, "points": 0},
{"id": "4612826", "name": "Ladd Mc", "in": True, "points": 0},
{"id": "4426388", "name": "Jameison Williams", "in": True, "points": 0},
{"id": "3121023", "name": "Goedhert", "in": True, "points": 0},
{"id": "4036133", "name": "TJ Hock", "in": True, "points": 0}],}

player_ids = []
for team_name, team_players in team_stats.items():
    for player in team_players:
        player_ids.append(player['id'])

player_points = {k: 0 for k in player_ids}

stats = {"passingYards": .04, "passingTouchdowns": 4, "interceptions": -2, "twoPtPass": 2, "rushingYards": .1, "rushingTouchdowns": 6, "twoPtRush": 2, "receivingYards": .1, "receptions": 1, "receivingTouchdowns": 6, "twoPtReception": 2, "fumblesLost": -2}

events = data["items"]

for event_url in events:
    event_bytes = fetch_data_from_url(event_url['$ref'])
    event_data = json.loads(event_bytes.decode())

    competitors = event_data['competitions'][0]['competitors']
    event_id = event_data['competitions'][0]["id"]
    teams = []
    for competitor in competitors:
        teams.append(competitor['id'])

    for team_name, team_players in team_stats.items():
        for player_data in team_players:
            print(f"Processing: {player_data['name']}")
            total_points = 0
            player = player_data['id']
            for team in teams[:1]:

                stats_url = f"http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/events/{event_id}/competitions/{event_id}/competitors/{team}/roster/{player}/statistics/0"
                maybe_stat_bytes = fetch_data_from_url(stats_url)
                if maybe_stat_bytes is None:
                    continue 
                data = json.loads(maybe_stat_bytes.decode())

                added = set()
                for cat in data["splits"]["categories"]:
                    for stat in cat["stats"]:
                        name, value = stat['name'], stat['value']

                        if name in stats.keys():
                            if name in added:
                                continue
                            added.add(name)
                            total_points += value * stats[name]
                            print(f"Adding {name}: {value} * {stats[name]}")

                player_points[player_id] += total_points

                print(f"Adding {total_points}: {player_data['name']}")
                player_data["points"] += total_points
            


print(team_stats)
# Out:
# Processing: Big Josh
# Adding fumblesLost: 0.0 * -2
# Adding interceptions: 0.0 * -2
# Adding passingTouchdowns: 2.0 * 4
# Adding passingYards: 272.0 * 0.04
# Adding twoPtPass: 1.0 * 2
# Adding rushingTouchdowns: 0.0 * 6
# Adding rushingYards: 46.0 * 0.1
# Adding twoPtRush: 0.0 * 2
# Adding receivingTouchdowns: 0.0 * 6
# Adding receivingYards: 0.0 * 0.1
# Adding receptions: 0.0 * 1
# Adding twoPtReception: 0.0 * 2
# Adding 25.480000000000004: Big Josh
# Processing: Aaron Jones
# Failed to retrieve data. Status code: 404
# Processing: Rashaad White
# Failed to retrieve data. Status code: 404
# Processing: AJ Brown
# Failed to retrieve data. Status code: 404
# Processing: Bateman
# Failed to retrieve data. Status code: 404
# Processing: T Kelce
# Failed to retrieve data. Status code: 404
# Processing: D Hop
# Failed to retrieve data. Status code: 404
# Processing: Stafford
# Failed to retrieve data. Status code: 404
# Processing: J Jacobs
# Failed to retrieve data. Status code: 404
# Processing: Kyrien Williams
# Failed to retrieve data. Status code: 404
# Processing: Amon Ra
# Failed to retrieve data. Status code: 404
# Processing: Puka Nacua
# Failed to retrieve data. Status code: 404
# Processing: Mark Andrews
# Failed to retrieve data. Status code: 404
# Processing: Khalil Shakir
# Adding fumblesLost: 0.0 * -2
# Adding interceptions: 0.0 * -2
# Adding passingTouchdowns: 0.0 * 4
# Adding passingYards: 0.0 * 0.04
# Adding twoPtPass: 0.0 * 2
# Adding rushingTouchdowns: 0.0 * 6
# Adding rushingYards: 0.0 * 0.1
# Adding twoPtRush: 0.0 * 2
# Adding receivingTouchdowns: 0.0 * 6
# Adding receivingYards: 61.0 * 0.1
# Adding receptions: 6.0 * 1
# Adding twoPtReception: 0.0 * 2
# Adding 12.100000000000001: Khalil Shakir
# Processing: J Hurts
# Failed to retrieve data. Status code: 404
# Processing: Mixon
# Failed to retrieve data. Status code: 404
# Processing: B Rob
# Failed to retrieve data. Status code: 404
# Processing: JJetas
# Failed to retrieve data. Status code: 404
# Processing: Mike Evans
# Failed to retrieve data. Status code: 404
# Processing: Zay Flowers
# Failed to retrieve data. Status code: 404
# Processing: Scary Terry
# Failed to retrieve data. Status code: 404
# Processing: Big Josh
# Failed to retrieve data. Status code: 404
# Processing: Aaron Jones
# Failed to retrieve data. Status code: 404
# Processing: Rashaad White
# Failed to retrieve data. Status code: 404
# Processing: AJ Brown
# Failed to retrieve data. Status code: 404
# Processing: Bateman
# Failed to retrieve data. Status code: 404
# Processing: T Kelce
# Failed to retrieve data. Status code: 404
# Processing: D Hop
# Failed to retrieve data. Status code: 404
# Processing: Stafford
# Failed to retrieve data. Status code: 404
# Processing: J Jacobs
# Failed to retrieve data. Status code: 404
# Processing: Kyrien Williams
# Failed to retrieve data. Status code: 404
# Processing: Amon Ra
# Failed to retrieve data. Status code: 404
# Processing: Puka Nacua
# Failed to retrieve data. Status code: 404
# Processing: Mark Andrews
# Failed to retrieve data. Status code: 404
# Processing: Khalil Shakir
# Failed to retrieve data. Status code: 404
# Processing: J Hurts
# Failed to retrieve data. Status code: 404
# Processing: Mixon
# Failed to retrieve data. Status code: 404
# Processing: B Rob
# Failed to retrieve data. Status code: 404
# Processing: JJetas
# Failed to retrieve data. Status code: 404
# Processing: Mike Evans
# Failed to retrieve data. Status code: 404
# Processing: Zay Flowers
# Failed to retrieve data. Status code: 404
# Processing: Scary Terry
# Failed to retrieve data. Status code: 404
# Processing: Big Josh
# Failed to retrieve data. Status code: 404
# Processing: Aaron Jones
# Failed to retrieve data. Status code: 404
# Processing: Rashaad White
# Failed to retrieve data. Status code: 404
# Processing: AJ Brown
# Failed to retrieve data. Status code: 404
# Processing: Bateman
# Failed to retrieve data. Status code: 404
# Processing: T Kelce
# Failed to retrieve data. Status code: 404
# Processing: D Hop
# Failed to retrieve data. Status code: 404
# Processing: Stafford
# Failed to retrieve data. Status code: 404
# Processing: J Jacobs
# Failed to retrieve data. Status code: 404
# Processing: Kyrien Williams
# Failed to retrieve data. Status code: 404
# Processing: Amon Ra
# Failed to retrieve data. Status code: 404
# Processing: Puka Nacua
# Failed to retrieve data. Status code: 404
# Processing: Mark Andrews
# Failed to retrieve data. Status code: 404
# Processing: Khalil Shakir
# Failed to retrieve data. Status code: 404
# Processing: J Hurts
# Failed to retrieve data. Status code: 404
# Processing: Mixon
# Failed to retrieve data. Status code: 404
# Processing: B Rob
# Failed to retrieve data. Status code: 404
# Processing: JJetas
# Failed to retrieve data. Status code: 404
# Processing: Mike Evans
# Failed to retrieve data. Status code: 404
# Processing: Zay Flowers
# Failed to retrieve data. Status code: 404
# Processing: Scary Terry
# Failed to retrieve data. Status code: 404
# Processing: Big Josh
# Failed to retrieve data. Status code: 404
# Processing: Aaron Jones
# Failed to retrieve data. Status code: 404
# Processing: Rashaad White
# Failed to retrieve data. Status code: 404
# Processing: AJ Brown
# Failed to retrieve data. Status code: 404
# Processing: Bateman
# Failed to retrieve data. Status code: 404
# Processing: T Kelce
# Failed to retrieve data. Status code: 404
# Processing: D Hop
# Failed to retrieve data. Status code: 404
# Processing: Stafford
# Failed to retrieve data. Status code: 404
# Processing: J Jacobs
# Failed to retrieve data. Status code: 404
# Processing: Kyrien Williams
# Failed to retrieve data. Status code: 404
# Processing: Amon Ra
# Failed to retrieve data. Status code: 404
# Processing: Puka Nacua
# Failed to retrieve data. Status code: 404
# Processing: Mark Andrews
# Failed to retrieve data. Status code: 404
# Processing: Khalil Shakir
# Failed to retrieve data. Status code: 404
# Processing: J Hurts
# Failed to retrieve data. Status code: 404
# Processing: Mixon
# Adding fumblesLost: 1.0 * -2
# Adding interceptions: 0.0 * -2
# Adding passingTouchdowns: 0.0 * 4
# Adding passingYards: 0.0 * 0.04
# Adding twoPtPass: 0.0 * 2
# Adding rushingTouchdowns: 1.0 * 6
# Adding rushingYards: 106.0 * 0.1
# Adding twoPtRush: 0.0 * 2
# Adding receivingTouchdowns: 0.0 * 6
# Adding receivingYards: 13.0 * 0.1
# Adding receptions: 1.0 * 1
# Adding twoPtReception: 0.0 * 2
# Adding 16.900000000000002: Mixon
# Processing: B Rob
# Failed to retrieve data. Status code: 404
# Processing: JJetas
# Failed to retrieve data. Status code: 404
# Processing: Mike Evans
# Failed to retrieve data. Status code: 404
# Processing: Zay Flowers
# Failed to retrieve data. Status code: 404
# Processing: Scary Terry
# Failed to retrieve data. Status code: 404
# Processing: Big Josh
# Failed to retrieve data. Status code: 404
# Processing: Aaron Jones
# Failed to retrieve data. Status code: 404
# Processing: Rashaad White
# Failed to retrieve data. Status code: 404
# Processing: AJ Brown
# Failed to retrieve data. Status code: 404
# Processing: Bateman
# Adding fumblesLost: 0.0 * -2
# Adding interceptions: 0.0 * -2
# Adding passingTouchdowns: 0.0 * 4
# Adding passingYards: 0.0 * 0.04
# Adding twoPtPass: 0.0 * 2
# Adding rushingTouchdowns: 0.0 * 6
# Adding rushingYards: 0.0 * 0.1
# Adding twoPtRush: 0.0 * 2
# Adding receivingTouchdowns: 1.0 * 6
# Adding receivingYards: 24.0 * 0.1
# Adding receptions: 2.0 * 1
# Adding twoPtReception: 0.0 * 2
# Adding 10.4: Bateman
# Processing: T Kelce
# Failed to retrieve data. Status code: 404
# Processing: D Hop
# Failed to retrieve data. Status code: 404
# Processing: Stafford
# Failed to retrieve data. Status code: 404
# Processing: J Jacobs
# Failed to retrieve data. Status code: 404
# Processing: Kyrien Williams
# Failed to retrieve data. Status code: 404
# Processing: Amon Ra
# Failed to retrieve data. Status code: 404
# Processing: Puka Nacua
# Failed to retrieve data. Status code: 404
# Processing: Mark Andrews
# Adding fumblesLost: 0.0 * -2
# Adding interceptions: 0.0 * -2
# Adding passingTouchdowns: 0.0 * 4
# Adding passingYards: 0.0 * 0.04
# Adding twoPtPass: 0.0 * 2
# Adding rushingTouchdowns: 0.0 * 6
# Adding rushingYards: 5.0 * 0.1
# Adding twoPtRush: 0.0 * 2
# Adding receivingTouchdowns: 0.0 * 6
# Adding receivingYards: 27.0 * 0.1
# Adding receptions: 2.0 * 1
# Adding twoPtReception: 0.0 * 2
# Adding 5.2: Mark Andrews
# Processing: Khalil Shakir
# Failed to retrieve data. Status code: 404
# Processing: J Hurts
# Failed to retrieve data. Status code: 404
# Processing: Mixon
# Failed to retrieve data. Status code: 404
# Processing: B Rob
# Failed to retrieve data. Status code: 404
# Processing: JJetas
# Failed to retrieve data. Status code: 404
# Processing: Mike Evans
# Failed to retrieve data. Status code: 404
# Processing: Zay Flowers
# Failed to retrieve data. Status code: 404
# Processing: Scary Terry
# Failed to retrieve data. Status code: 404
# Processing: Big Josh
# Failed to retrieve data. Status code: 404
# Processing: Aaron Jones
# Failed to retrieve data. Status code: 404
# Processing: Rashaad White
# Failed to retrieve data. Status code: 404
# Processing: AJ Brown
# Failed to retrieve data. Status code: 404
# Processing: Bateman
# Failed to retrieve data. Status code: 404
# Processing: T Kelce
# Failed to retrieve data. Status code: 404
# Processing: D Hop
# Failed to retrieve data. Status code: 404
# Processing: Stafford
# Failed to retrieve data. Status code: 404
# Processing: J Jacobs
# Failed to retrieve data. Status code: 404
# Processing: Kyrien Williams
# Failed to retrieve data. Status code: 404
# Processing: Amon Ra
# Failed to retrieve data. Status code: 404
# Processing: Puka Nacua
# Failed to retrieve data. Status code: 404
# Processing: Mark Andrews
# Failed to retrieve data. Status code: 404
# Processing: Khalil Shakir
# Failed to retrieve data. Status code: 404
# Processing: J Hurts
# Failed to retrieve data. Status code: 404
# Processing: Mixon
# Failed to retrieve data. Status code: 404
# Processing: B Rob
# Failed to retrieve data. Status code: 404
# Processing: JJetas
# Failed to retrieve data. Status code: 404
# Processing: Mike Evans
# Failed to retrieve data. Status code: 404
# Processing: Zay Flowers
# Failed to retrieve data. Status code: 404
# Processing: Scary Terry
# Failed to retrieve data. Status code: 404
# {'JJ': [{'id': '3918298', 'name': 'Big Josh', 'in': True, 'points': 25.480000000000004}, {'id': '3042519', 'name': 'Aaron Jones', 'in': True, 'points': 0}, {'id': '4697815', 'name': 'Rashaad White', 'in': True, 'points': 0}, {'id': '15828', 'name': 'AJ Brown', 'in': True, 'points': 0}, {'id': '4360939', 'name': 'Bateman', 'in': True, 'points': 10.4}, {'id': '15847', 'name': 'T Kelce', 'in': True, 'points': 0}, {'id': '15795', 'name': 'D Hop', 'in': True, 'points': 0}], 'BNIED': [{'id': '12483', 'name': 'Stafford', 'in': True, 'points': 0}, {'id': '4047365', 'name': 'J Jacobs', 'in': True, 'points': 0}, {'id': '4430737', 'name': 'Kyrien Williams', 'in': True, 'points': 0}, {'id': '4374302', 'name': 'Amon Ra', 'in': True, 'points': 0}, {'id': '4426515', 'name': 'Puka Nacua', 'in': True, 'points': 0}, {'id': '3116365', 'name': 'Mark Andrews', 'in': True, 'points': 5.2}, {'id': '4373678', 'name': 'Khalil Shakir', 'in': True, 'points': 12.100000000000001}], 'QUINN': [{'id': '4040715', 'name': 'J Hurts', 'in': True, 'points': 0}, {'id': '3116385', 'name': 'Mixon', 'in': True, 'points': 16.900000000000002}, {'id': '4241474', 'name': 'B Rob', 'in': True, 'points': 0}, {'id': '4262921', 'name': 'JJetas', 'in': True, 'points': 0}, {'id': '16737', 'name': 'Mike Evans', 'in': True, 'points': 0}, {'id': '4429615', 'name': 'Zay Flowers', 'in': True, 'points': 0}, {'id': '3121422', 'name': 'Scary Terry', 'in': True, 'points': 0}]}

# %%
import gspread
gc = gspread.service_account(filename="/Users/jjigims23/Desktop/fantasy/fantasy-447619-e04c138d90f0.json")

# Open a Google Sheet by its name
sheet = gc.open("NFL Playoff Fantasy").sheet1  # Access the first sheet

# Data to write (list of lists)
sheet.clear()

header = []
team_names = team_stats.keys()
for team_name in team_names:
    header += [team_name, "score"]
# data = [[] * 10]
# for team_name, team_players in teams.items():
  
data = [
    header,
]
sheet.update("A1", data)

data = [[] for i in range(8)]
print(team_stats)
team_totals = {k: 0 for k, _ in team_stats.items()}
for team_name, team_players in team_stats.items():
    for idx, player in enumerate(team_players):
        data[idx] += [player["name"], player["points"]]
        print(data)
        team_totals[team_name] += player["points"]
  
sheet.update("A2", data)

data = [[]]
for k, v in team_totals.items():
    data[0] += ["", v]
print(data)
sheet.update("A9", data)


# Clear the sheet before writing new data

# Write the data to the sheet
# Out:
# /var/folders/j_/8zs8mcy55l97jkwvq8k79tsh0000gn/T/ipykernel_77501/908936082.py:20: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   sheet.update("A1", data)
# /var/folders/j_/8zs8mcy55l97jkwvq8k79tsh0000gn/T/ipykernel_77501/908936082.py:31: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   sheet.update("A2", data)
# {'JJ': [{'id': '3918298', 'name': 'Big Josh', 'in': True, 'points': 25.480000000000004}, {'id': '3042519', 'name': 'Aaron Jones', 'in': True, 'points': 0}, {'id': '4697815', 'name': 'Rashaad White', 'in': True, 'points': 0}, {'id': '15828', 'name': 'AJ Brown', 'in': True, 'points': 0}, {'id': '4360939', 'name': 'Bateman', 'in': True, 'points': 10.4}, {'id': '15847', 'name': 'T Kelce', 'in': True, 'points': 0}, {'id': '15795', 'name': 'D Hop', 'in': True, 'points': 0}], 'BNIED': [{'id': '12483', 'name': 'Stafford', 'in': True, 'points': 0}, {'id': '4047365', 'name': 'J Jacobs', 'in': True, 'points': 0}, {'id': '4430737', 'name': 'Kyrien Williams', 'in': True, 'points': 0}, {'id': '4374302', 'name': 'Amon Ra', 'in': True, 'points': 0}, {'id': '4426515', 'name': 'Puka Nacua', 'in': True, 'points': 0}, {'id': '3116365', 'name': 'Mark Andrews', 'in': True, 'points': 5.2}, {'id': '4373678', 'name': 'Khalil Shakir', 'in': True, 'points': 12.100000000000001}], 'QUINN': [{'id': '4040715', 'name': 'J Hurts', 'in': True, 'points': 0}, {'id': '3116385', 'name': 'Mixon', 'in': True, 'points': 16.900000000000002}, {'id': '4241474', 'name': 'B Rob', 'in': True, 'points': 0}, {'id': '4262921', 'name': 'JJetas', 'in': True, 'points': 0}, {'id': '16737', 'name': 'Mike Evans', 'in': True, 'points': 0}, {'id': '4429615', 'name': 'Zay Flowers', 'in': True, 'points': 0}, {'id': '3121422', 'name': 'Scary Terry', 'in': True, 'points': 0}]}
# [['Big Josh', 25.480000000000004], [], [], [], [], [], [], []]
# [['Big Josh', 25.480000000000004], ['Aaron Jones', 0], [], [], [], [], [], []]
# [['Big Josh', 25.480000000000004], ['Aaron Jones', 0], ['Rashaad White', 0], [], [], [], [], []]
# [['Big Josh', 25.480000000000004], ['Aaron Jones', 0], ['Rashaad White', 0], ['AJ Brown', 0], [], [], [], []]
# [['Big Josh', 25.480000000000004], ['Aaron Jones', 0], ['Rashaad White', 0], ['AJ Brown', 0], ['Bateman', 10.4], [], [], []]
# [['Big Josh', 25.480000000000004], ['Aaron Jones', 0], ['Rashaad White', 0], ['AJ Brown', 0], ['Bateman', 10.4], ['T Kelce', 0], [], []]
# [['Big Josh', 25.480000000000004], ['Aaron Jones', 0], ['Rashaad White', 0], ['AJ Brown', 0], ['Bateman', 10.4], ['T Kelce', 0], ['D Hop', 0], []]
# [['Big Josh', 25.480000000000004, 'Stafford', 0], ['Aaron Jones', 0], ['Rashaad White', 0], ['AJ Brown', 0], ['Bateman', 10.4], ['T Kelce', 0], ['D Hop', 0], []]
# [['Big Josh', 25.480000000000004, 'Stafford', 0], ['Aaron Jones', 0, 'J Jacobs', 0], ['Rashaad White', 0], ['AJ Brown', 0], ['Bateman', 10.4], ['T Kelce', 0], ['D Hop', 0], []]
# [['Big Josh', 25.480000000000004, 'Stafford', 0], ['Aaron Jones', 0, 'J Jacobs', 0], ['Rashaad White', 0, 'Kyrien Williams', 0], ['AJ Brown', 0], ['Bateman', 10.4], ['T Kelce', 0], ['D Hop', 0], []]
# [['Big Josh', 25.480000000000004, 'Stafford', 0], ['Aaron Jones', 0, 'J Jacobs', 0], ['Rashaad White', 0, 'Kyrien Williams', 0], ['AJ Brown', 0, 'Amon Ra', 0], ['Bateman', 10.4], ['T Kelce', 0], ['D Hop', 0], []]
# [['Big Josh', 25.480000000000004, 'Stafford', 0], ['Aaron Jones', 0, 'J Jacobs', 0], ['Rashaad White', 0, 'Kyrien Williams', 0], ['AJ Brown', 0, 'Amon Ra', 0], ['Bateman', 10.4, 'Puka Nacua', 0], ['T Kelce', 0], ['D Hop', 0], []]
# [['Big Josh', 25.480000000000004, 'Stafford', 0], ['Aaron Jones', 0, 'J Jacobs', 0], ['Rashaad White', 0, 'Kyrien Williams', 0], ['AJ Brown', 0, 'Amon Ra', 0], ['Bateman', 10.4, 'Puka Nacua', 0], ['T Kelce', 0, 'Mark Andrews', 5.2], ['D Hop', 0], []]
# [['Big Josh', 25.480000000000004, 'Stafford', 0], ['Aaron Jones', 0, 'J Jacobs', 0], ['Rashaad White', 0, 'Kyrien Williams', 0], ['AJ Brown', 0, 'Amon Ra', 0], ['Bateman', 10.4, 'Puka Nacua', 0], ['T Kelce', 0, 'Mark Andrews', 5.2], ['D Hop', 0, 'Khalil Shakir', 12.100000000000001], []]
# [['Big Josh', 25.480000000000004, 'Stafford', 0, 'J Hurts', 0], ['Aaron Jones', 0, 'J Jacobs', 0], ['Rashaad White', 0, 'Kyrien Williams', 0], ['AJ Brown', 0, 'Amon Ra', 0], ['Bateman', 10.4, 'Puka Nacua', 0], ['T Kelce', 0, 'Mark Andrews', 5.2], ['D Hop', 0, 'Khalil Shakir', 12.100000000000001], []]
# [['Big Josh', 25.480000000000004, 'Stafford', 0, 'J Hurts', 0], ['Aaron Jones', 0, 'J Jacobs', 0, 'Mixon', 16.900000000000002], ['Rashaad White', 0, 'Kyrien Williams', 0], ['AJ Brown', 0, 'Amon Ra', 0], ['Bateman', 10.4, 'Puka Nacua', 0], ['T Kelce', 0, 'Mark Andrews', 5.2], ['D Hop', 0, 'Khalil Shakir', 12.100000000000001], []]
# [['Big Josh', 25.480000000000004, 'Stafford', 0, 'J Hurts', 0], ['Aaron Jones', 0, 'J Jacobs', 0, 'Mixon', 16.900000000000002], ['Rashaad White', 0, 'Kyrien Williams', 0, 'B Rob', 0], ['AJ Brown', 0, 'Amon Ra', 0], ['Bateman', 10.4, 'Puka Nacua', 0], ['T Kelce', 0, 'Mark Andrews', 5.2], ['D Hop', 0, 'Khalil Shakir', 12.100000000000001], []]
# [['Big Josh', 25.480000000000004, 'Stafford', 0, 'J Hurts', 0], ['Aaron Jones', 0, 'J Jacobs', 0, 'Mixon', 16.900000000000002], ['Rashaad White', 0, 'Kyrien Williams', 0, 'B Rob', 0], ['AJ Brown', 0, 'Amon Ra', 0, 'JJetas', 0], ['Bateman', 10.4, 'Puka Nacua', 0], ['T Kelce', 0, 'Mark Andrews', 5.2], ['D Hop', 0, 'Khalil Shakir', 12.100000000000001], []]
# [['Big Josh', 25.480000000000004, 'Stafford', 0, 'J Hurts', 0], ['Aaron Jones', 0, 'J Jacobs', 0, 'Mixon', 16.900000000000002], ['Rashaad White', 0, 'Kyrien Williams', 0, 'B Rob', 0], ['AJ Brown', 0, 'Amon Ra', 0, 'JJetas', 0], ['Bateman', 10.4, 'Puka Nacua', 0, 'Mike Evans', 0], ['T Kelce', 0, 'Mark Andrews', 5.2], ['D Hop', 0, 'Khalil Shakir', 12.100000000000001], []]
# [['Big Josh', 25.480000000000004, 'Stafford', 0, 'J Hurts', 0], ['Aaron Jones', 0, 'J Jacobs', 0, 'Mixon', 16.900000000000002], ['Rashaad White', 0, 'Kyrien Williams', 0, 'B Rob', 0], ['AJ Brown', 0, 'Amon Ra', 0, 'JJetas', 0], ['Bateman', 10.4, 'Puka Nacua', 0, 'Mike Evans', 0], ['T Kelce', 0, 'Mark Andrews', 5.2, 'Zay Flowers', 0], ['D Hop', 0, 'Khalil Shakir', 12.100000000000001], []]
# [['Big Josh', 25.480000000000004, 'Stafford', 0, 'J Hurts', 0], ['Aaron Jones', 0, 'J Jacobs', 0, 'Mixon', 16.900000000000002], ['Rashaad White', 0, 'Kyrien Williams', 0, 'B Rob', 0], ['AJ Brown', 0, 'Amon Ra', 0, 'JJetas', 0], ['Bateman', 10.4, 'Puka Nacua', 0, 'Mike Evans', 0], ['T Kelce', 0, 'Mark Andrews', 5.2, 'Zay Flowers', 0], ['D Hop', 0, 'Khalil Shakir', 12.100000000000001, 'Scary Terry', 0], []]
# [['', 35.88, '', 17.3, '', 16.900000000000002]]
# /var/folders/j_/8zs8mcy55l97jkwvq8k79tsh0000gn/T/ipykernel_77501/908936082.py:37: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   sheet.update("A9", data)
# {'spreadsheetId': '1TtVnaoGtJiBpsrdmIGdYjky5kgJUM3-9Jeb_ZqdVTkI',
#  'updatedRange': 'Sheet1!A9:F9',
#  'updatedRows': 1,
#  'updatedColumns': 6,
#  'updatedCells': 6}
